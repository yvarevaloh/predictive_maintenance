# %% [markdown]
# <h1 align=center> BibTeX in Jupyter<h1>
# <h4 align=center> How to include a bibliography?</h4>
# <br>
# <img align=left src="https://raw.githubusercontent.com/jupyter/nature-demo/master/images/jupyter-logo.png" width="350px" style="margin-left: 100px;">
# <img align=right src="https://upload.wikimedia.org/wikipedia/commons/3/30/BibTeX_logo.svg" width="350px" style="margin-right: 100px;">

# %% [markdown]
# # Install $\LaTeX$ and BibTeX
# ```bash
# sudo apt-get install texlive-latex-extra
# sudo apt-get install texlive-bibtex-extra
# ```

# %% [markdown]
# # What we need?
# - A Jupyter file (.ipynb)
# - A BibTeX file (.bib)
# - A template file (.tplex)

# %%
# %%bash
# ipython nbconvert --to latex --template citations.tplx version2_presentation.ipynb
# pdflatex version2_presentation.tex
# bibtex version2_presentation
# pdflatex version2_presentation.tex
# Out:
# This is pdfTeX, Version 3.14159265-2.6-1.40.21 (MiKTeX 2.9.7400 64-bit)
# entering extended mode
# (version2_presentation.tex
# LaTeX2e <2020-02-02> patch level 5
# L3 programming layer <2020-04-06>
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\article.cls"
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\size11.clo"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/tcolorbox\tcolorbox
# .sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/basiclayer\pgf.
# sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/utilities\pgfrc
# s.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# util-common.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# util-common-lists.tex"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# util-latex.def"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ms\everyshi.sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# rcs.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf\pgf.revision.
# tex")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/basiclayer\pgfc
# ore.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics\graphicx.s
# ty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics\keyval.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics\graphics.s
# ty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics\trig.sty")
#
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics-cfg\graphi
# cs.cfg")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics-def\pdftex
# .def")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/systemlayer\pgf
# sys.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gfsys.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# keys.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# keysfiltered.code.tex"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gf.cfg")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gfsys-pdftex.def"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gfsys-common-pdf.def")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gfsyssoftpath.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gfsysprotocol.code.tex"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/xcolor\xcolor.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics-cfg\color.
# cfg"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcore.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmath.
# code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathc
# alc.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathu
# til.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathp
# arser.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.basic.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.trigonometric.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.random.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.comparison.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.base.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.round.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.misc.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.integerarithmetics.code.tex")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# loat.code.tex"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfint.c
# ode.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorepoints.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorepathconstruct.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorepathusage.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorescopes.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoregraphicstate.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoretransformations.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorequick.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoreobjects.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorepathprocessing.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorearrows.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoreshade.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoreimage.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoreexternal.code.tex"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorelayers.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoretransparency.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorepatterns.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorerdf.code.tex")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/modules\pgfmo
# duleshapes.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/modules\pgfmo
# duleplot.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/compatibility\p
# gfcomp-version-0-65.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/compatibility\p
# gfcomp-version-1-18.sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/tools\verbatim.sty"
# )
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/environ\environ.sty
# "
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/trimspaces\trimspac
# es.sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/etoolbox\etoolbox.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/tcolorbox\tcbbreaka
# ble.code.tex"
# Library (tcolorbox): 'tcbbreakable.code.tex' version '4.22'
# ))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/parskip\parskip.sty
# "
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/kvoptions\kvoptions
# .sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/ltxcmds\ltxcmds.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/kvsetkeys\kvsetke
# ys.sty")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/iftex\iftex.sty")
#  ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\fontenc.sty")
#  ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\mathpazo.st
# y")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/caption\caption.sty
# "
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/caption\caption3.st
# y"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/adjustbox\adjustbox
# .sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/xkeyval\xkeyval.sty
# "
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/xkeyval\xkeyval.t
# ex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/xkeyval\xkvutils.
# tex")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/adjustbox\adjcalc.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/adjustbox\trimclip.
# sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/collectbox\collectb
# ox.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/adjustbox\tc-pdftex
# .def"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ifoddpage\ifoddpage
# .sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/varwidth\varwidth.s
# ty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/float\float.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/tools\enumerate.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/geometry\geometry.s
# ty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/iftex\ifvtex.sty"
# )
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/geometry\geometry.c
# fg"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsmath\amsmath.sty
# "
# For additional information on amsmath, use the `?' option.
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsmath\amstext.sty
# " ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsmath\amsgen.st
# y"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsmath\amsbsy.sty"
# ) ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsmath\amsopn.st
# y"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsfonts\amssymb.st
# y"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsfonts\amsfonts.s
# ty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\textcomp.sty")
#  ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/upquote\upquote.st
# y")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/eurosym\eurosym.sty
# ") ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ucs\ucs.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ucs\uni-global.def"
# ))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/fancyvrb\fancyvrb.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/grffile\grffile.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/hyperref\hyperref.s
# ty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pdftexcmds\pdftexcm
# ds.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/infwarerr\infware
# rr.sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/kvdefinekeys\kvde
# finekeys.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pdfescape\pdfesca
# pe.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/hycolor\hycolor.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/letltxmacro\letltxm
# acro.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/auxhook\auxhook.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/hyperref\pd1enc.def
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/intcalc\intcalc.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/etexcmds\etexcmds
# .sty") ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/url\url.sty"
# )
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/bitset\bitset.sty
# "
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/bigintcalc\bigint
# calc.sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/atbegshi\atbegshi
# .sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/hyperref\hpdftex.de
# f"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/atveryend\atveryend
# .sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/rerunfilecheck\reru
# nfilecheck.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/uniquecounter\uni
# quecounter.sty")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/titling\titling.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/tools\longtable.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/booktabs\booktabs.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/enumitem\enumitem.s
# ty") ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ulem\ulem.sty"
# )
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/jknappen\mathrsfs.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/l3backend\l3backend
# -pdfmode.def") (version2_presentation.aux)
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\t1ppl.fd")
# ABD: EveryShipout initializing macros
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/context/base/mkii\supp-pd
# f.mkii"
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/epstopdf-pkg\epstop
# df-base.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/caption\ltcaption.s
# ty")
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# *geometry* verbose mode - [ preamble ] result:
# * driver: pdftex
# * paper: <default>
# * layout: <same size as paper>
# * layoutoffset:(h,v)=(0.0pt,0.0pt)
# * modes:
# * h-part:(L,W,R)=(72.26999pt, 469.75502pt, 72.26999pt)
# * v-part:(T,H,B)=(72.26999pt, 650.43001pt, 72.26999pt)
# * \paperwidth=614.295pt
# * \paperheight=794.96999pt
# * \textwidth=469.75502pt
# * \textheight=650.43001pt
# * \oddsidemargin=0.0pt
# * \evensidemargin=0.0pt
# * \topmargin=-37.0pt
# * \headheight=12.0pt
# * \headsep=25.0pt
# * \topskip=11.0pt
# * \footskip=30.0pt
# * \marginparwidth=59.0pt
# * \marginparsep=10.0pt
# * \columnsep=10.0pt
# * \skip\footins=10.0pt plus 4.0pt minus 2.0pt
# * \hoffset=0.0pt
# * \voffset=0.0pt
# * \mag=1000
# * \@twocolumnfalse
# * \@twosidefalse
# * \@mparswitchfalse
# * \@reversemarginfalse
# * (1in=72.27pt=25.4mm, 1cm=28.453pt)
#
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ucs\ucsencs.def")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/hyperref\nameref.st
# y"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/refcount\refcount.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/gettitlestring\ge
# ttitlestring.sty")) (version2_presentation.out) (version2_presentation.out)
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\ot1ppl.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\omlzplm.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\omszplm.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\omxzplm.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\ot1zplm.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/jknappen\ursfs.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\t1cmtt.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\ts1cmtt.fd")
# [1{C:/Users/vivi/AppData/Local/MiKTeX/2.9/pdftex/config/pdftex.map} <./3DTechLo
# go.png>] [2 <./summay_data.png>] [3]
# Overfull \hbox (13.54814pt too wide) in paragraph at lines 568--568
# []|\T1/cmtt/m/n/10.95 varx[]=[][[]\TS1/cmtt/m/n/10.95 '[][]\T1/cmtt/m/n/10.95 a
# ttribute1[][]\TS1/cmtt/m/n/10.95 '[]\T1/cmtt/m/n/10.95 ,[]\TS1/cmtt/m/n/10.95 '
# [][]\T1/cmtt/m/n/10.95 attribute2[][]\TS1/cmtt/m/n/10.95 '[]\T1/cmtt/m/n/10.95
# ,[]\TS1/cmtt/m/n/10.95 '[][]\T1/cmtt/m/n/10.95 attribute3[][]\TS1/cmtt/m/n/10.9
# 5 '[]\T1/cmtt/m/n/10.95 ,[]\TS1/cmtt/m/n/10.95 '[][]\T1/cmtt/m/n/10.95 attribut
# e4[][]\TS1/cmtt/m/n/10.95 '[]\T1/cmtt/m/n/10.95 ,[]\TS1/cmtt/m/n/10.95 '[][]\T1
# /cmtt/m/n/10.95 attribute5[][]\TS1/cmtt/m/n/10.95 '[]\T1/cmtt/m/n/10.95 ,[]\TS1
# /cmtt/m/n/10.95 '[][]\T1/cmtt/m/n/10.95 attribute6[][]\TS1/cmtt/m/n/10.95 '[]\T
# 1/cmtt/m/n/10.95 ,|
# [4] [5]
# Underfull \hbox (badness 10000) in paragraph at lines 669--670
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 702--703
#
# [6 <./version2_presentation_files/version2_presentation_16_0.png>] [7]
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\ts1ppl.fd")
# Underfull \hbox (badness 10000) in paragraph at lines 864--867
#
# [8] [9]
# Underfull \hbox (badness 10000) in paragraph at lines 988--989
#
# [10 <./version2_presentation_files/version2_presentation_42_0.png>]
# Underfull \hbox (badness 10000) in paragraph at lines 1061--1062
#
# [11 <./version2_presentation_files/version2_presentation_47_0.png>] [12]
# Underfull \hbox (badness 10000) in paragraph at lines 1152--1153
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 1163--1164
#
# [13 <./version2_presentation_files/version2_presentation_54_0.png>] [14]
# [15] (version2_presentation.bbl [16]) [17] (version2_presentation.aux)
#
# Package rerunfilecheck Warning: File `version2_presentation.out' has changed.
# (rerunfilecheck)                Rerun to get outlines right
# (rerunfilecheck)                or use package `bookmark'.
#
#
# LaTeX Warning: Label(s) may have changed. Rerun to get cross-references right.
#
#  )
# (see the transcript file for additional information){C:/Users/vivi/AppData/Loca
# l/Programs/MiKTeX 2.9/fonts/enc/dvips/base/8r.enc} <C:\Users\vivi\AppData\Local
# \MiKTeX\2.9\fonts/pk/ljfour/jknappen/ec/dpi600\tcit1095.pk> <C:\Users\vivi\AppD
# ata\Local\MiKTeX\2.9\fonts/pk/ljfour/jknappen/ec/dpi600\ecit1095.pk> <C:\Users\
# vivi\AppData\Local\MiKTeX\2.9\fonts/pk/ljfour/jknappen/ec/dpi600\tctt1095.pk> <
# C:\Users\vivi\AppData\Local\MiKTeX\2.9\fonts/pk/ljfour/jknappen/ec/dpi600\ectt1
# 095.pk><C:/Users/vivi/AppData/Local/Programs/MiKTeX 2.9/fonts/type1/public/amsf
# onts/cm/cmmi10.pfb><C:/Users/vivi/AppData/Local/Programs/MiKTeX 2.9/fonts/type1
# /public/amsfonts/cm/cmsy10.pfb><C:/Users/vivi/AppData/Local/Programs/MiKTeX 2.9
# /fonts/type1/urw/palatino/uplb8a.pfb><C:/Users/vivi/AppData/Local/Programs/MiKT
# eX 2.9/fonts/type1/urw/palatino/uplr8a.pfb><C:/Users/vivi/AppData/Local/Program
# s/MiKTeX 2.9/fonts/type1/urw/palatino/uplri8a.pfb>
# Output written on version2_presentation.pdf (17 pages, 330568 bytes).
# Transcript written on version2_presentation.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.21 (MiKTeX 2.9.7400 64-bit)
# entering extended mode
# (version2_presentation.tex
# LaTeX2e <2020-02-02> patch level 5
# L3 programming layer <2020-04-06>
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\article.cls"
# Document Class: article 2019/12/20 v1.4l Standard LaTeX document class
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\size11.clo"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/tcolorbox\tcolorbox
# .sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/basiclayer\pgf.
# sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/utilities\pgfrc
# s.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# util-common.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# util-common-lists.tex"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# util-latex.def"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ms\everyshi.sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# rcs.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf\pgf.revision.
# tex")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/basiclayer\pgfc
# ore.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics\graphicx.s
# ty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics\keyval.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics\graphics.s
# ty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics\trig.sty")
#
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics-cfg\graphi
# cs.cfg")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics-def\pdftex
# .def")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/systemlayer\pgf
# sys.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gfsys.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# keys.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/utilities\pgf
# keysfiltered.code.tex"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gf.cfg")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gfsys-pdftex.def"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gfsys-common-pdf.def")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gfsyssoftpath.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/systemlayer\p
# gfsysprotocol.code.tex"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/xcolor\xcolor.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/graphics-cfg\color.
# cfg"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcore.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmath.
# code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathc
# alc.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathu
# til.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathp
# arser.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.basic.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.trigonometric.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.random.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.comparison.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.base.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.round.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.misc.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# unctions.integerarithmetics.code.tex")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfmathf
# loat.code.tex"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/math\pgfint.c
# ode.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorepoints.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorepathconstruct.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorepathusage.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorescopes.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoregraphicstate.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoretransformations.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorequick.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoreobjects.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorepathprocessing.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorearrows.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoreshade.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoreimage.code.tex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoreexternal.code.tex"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorelayers.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcoretransparency.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorepatterns.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/basiclayer\pg
# fcorerdf.code.tex")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/modules\pgfmo
# duleshapes.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pgf/modules\pgfmo
# duleplot.code.tex")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/compatibility\p
# gfcomp-version-0-65.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pgf/compatibility\p
# gfcomp-version-1-18.sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/tools\verbatim.sty"
# )
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/environ\environ.sty
# "
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/trimspaces\trimspac
# es.sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/etoolbox\etoolbox.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/tcolorbox\tcbbreaka
# ble.code.tex"
# Library (tcolorbox): 'tcbbreakable.code.tex' version '4.22'
# ))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/parskip\parskip.sty
# "
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/kvoptions\kvoptions
# .sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/ltxcmds\ltxcmds.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/kvsetkeys\kvsetke
# ys.sty")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/iftex\iftex.sty")
#  ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\fontenc.sty")
#  ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\mathpazo.st
# y")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/caption\caption.sty
# "
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/caption\caption3.st
# y"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/adjustbox\adjustbox
# .sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/xkeyval\xkeyval.sty
# "
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/xkeyval\xkeyval.t
# ex"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/xkeyval\xkvutils.
# tex")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/adjustbox\adjcalc.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/adjustbox\trimclip.
# sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/collectbox\collectb
# ox.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/adjustbox\tc-pdftex
# .def"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ifoddpage\ifoddpage
# .sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/varwidth\varwidth.s
# ty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/float\float.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/tools\enumerate.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/geometry\geometry.s
# ty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/iftex\ifvtex.sty"
# )
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/geometry\geometry.c
# fg"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsmath\amsmath.sty
# "
# For additional information on amsmath, use the `?' option.
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsmath\amstext.sty
# " ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsmath\amsgen.st
# y"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsmath\amsbsy.sty"
# ) ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsmath\amsopn.st
# y"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsfonts\amssymb.st
# y"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/amsfonts\amsfonts.s
# ty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\textcomp.sty")
#  ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/upquote\upquote.st
# y")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/eurosym\eurosym.sty
# ") ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ucs\ucs.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ucs\uni-global.def"
# ))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/fancyvrb\fancyvrb.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/grffile\grffile.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/hyperref\hyperref.s
# ty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/pdftexcmds\pdftexcm
# ds.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/infwarerr\infware
# rr.sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/kvdefinekeys\kvde
# finekeys.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/pdfescape\pdfesca
# pe.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/hycolor\hycolor.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/letltxmacro\letltxm
# acro.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/auxhook\auxhook.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/hyperref\pd1enc.def
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/intcalc\intcalc.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/etexcmds\etexcmds
# .sty") ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/url\url.sty"
# )
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/bitset\bitset.sty
# "
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/bigintcalc\bigint
# calc.sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/atbegshi\atbegshi
# .sty"))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/hyperref\hpdftex.de
# f"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/atveryend\atveryend
# .sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/rerunfilecheck\reru
# nfilecheck.sty"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/uniquecounter\uni
# quecounter.sty")))
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/titling\titling.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/tools\longtable.sty
# ")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/booktabs\booktabs.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/enumitem\enumitem.s
# ty") ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ulem\ulem.sty"
# )
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/jknappen\mathrsfs.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/l3backend\l3backend
# -pdfmode.def") (version2_presentation.aux)
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\t1ppl.fd")
# ABD: EveryShipout initializing macros
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/context/base/mkii\supp-pd
# f.mkii"
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/epstopdf-pkg\epstop
# df-base.sty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/caption\ltcaption.s
# ty")
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
# *geometry* verbose mode - [ preamble ] result:
# * driver: pdftex
# * paper: <default>
# * layout: <same size as paper>
# * layoutoffset:(h,v)=(0.0pt,0.0pt)
# * modes:
# * h-part:(L,W,R)=(72.26999pt, 469.75502pt, 72.26999pt)
# * v-part:(T,H,B)=(72.26999pt, 650.43001pt, 72.26999pt)
# * \paperwidth=614.295pt
# * \paperheight=794.96999pt
# * \textwidth=469.75502pt
# * \textheight=650.43001pt
# * \oddsidemargin=0.0pt
# * \evensidemargin=0.0pt
# * \topmargin=-37.0pt
# * \headheight=12.0pt
# * \headsep=25.0pt
# * \topskip=11.0pt
# * \footskip=30.0pt
# * \marginparwidth=59.0pt
# * \marginparsep=10.0pt
# * \columnsep=10.0pt
# * \skip\footins=10.0pt plus 4.0pt minus 2.0pt
# * \hoffset=0.0pt
# * \voffset=0.0pt
# * \mag=1000
# * \@twocolumnfalse
# * \@twosidefalse
# * \@mparswitchfalse
# * \@reversemarginfalse
# * (1in=72.27pt=25.4mm, 1cm=28.453pt)
#
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/ucs\ucsencs.def")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/hyperref\nameref.st
# y"
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/refcount\refcount.s
# ty")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/generic/gettitlestring\ge
# ttitlestring.sty")) (version2_presentation.out) (version2_presentation.out)
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\ot1ppl.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\omlzplm.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\omszplm.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\omxzplm.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\ot1zplm.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/jknappen\ursfs.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\t1cmtt.fd")
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/base\ts1cmtt.fd")
# [1{C:/Users/vivi/AppData/Local/MiKTeX/2.9/pdftex/config/pdftex.map} <./3DTechLo
# go.png>] [2 <./summay_data.png>] [3]
# Overfull \hbox (13.54814pt too wide) in paragraph at lines 568--568
# []|\T1/cmtt/m/n/10.95 varx[]=[][[]\TS1/cmtt/m/n/10.95 '[][]\T1/cmtt/m/n/10.95 a
# ttribute1[][]\TS1/cmtt/m/n/10.95 '[]\T1/cmtt/m/n/10.95 ,[]\TS1/cmtt/m/n/10.95 '
# [][]\T1/cmtt/m/n/10.95 attribute2[][]\TS1/cmtt/m/n/10.95 '[]\T1/cmtt/m/n/10.95
# ,[]\TS1/cmtt/m/n/10.95 '[][]\T1/cmtt/m/n/10.95 attribute3[][]\TS1/cmtt/m/n/10.9
# 5 '[]\T1/cmtt/m/n/10.95 ,[]\TS1/cmtt/m/n/10.95 '[][]\T1/cmtt/m/n/10.95 attribut
# e4[][]\TS1/cmtt/m/n/10.95 '[]\T1/cmtt/m/n/10.95 ,[]\TS1/cmtt/m/n/10.95 '[][]\T1
# /cmtt/m/n/10.95 attribute5[][]\TS1/cmtt/m/n/10.95 '[]\T1/cmtt/m/n/10.95 ,[]\TS1
# /cmtt/m/n/10.95 '[][]\T1/cmtt/m/n/10.95 attribute6[][]\TS1/cmtt/m/n/10.95 '[]\T
# 1/cmtt/m/n/10.95 ,|
# [4] [5]
# Underfull \hbox (badness 10000) in paragraph at lines 669--670
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 702--703
#
# [6 <./version2_presentation_files/version2_presentation_16_0.png>] [7]
# ("C:\Users\vivi\AppData\Local\Programs\MiKTeX 2.9\tex/latex/psnfss\ts1ppl.fd")
# Underfull \hbox (badness 10000) in paragraph at lines 864--867
#
# [8] [9]
# Underfull \hbox (badness 10000) in paragraph at lines 988--989
#
# [10 <./version2_presentation_files/version2_presentation_42_0.png>]
# Underfull \hbox (badness 10000) in paragraph at lines 1061--1062
#
# [11 <./version2_presentation_files/version2_presentation_47_0.png>] [12]
# Underfull \hbox (badness 10000) in paragraph at lines 1152--1153
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 1163--1164
#
# [13 <./version2_presentation_files/version2_presentation_54_0.png>] [14]
# [15] (version2_presentation.bbl [16]) [17] (version2_presentation.aux) )
# (see the transcript file for additional information){C:/Users/vivi/AppData/Loca
# l/Programs/MiKTeX 2.9/fonts/enc/dvips/base/8r.enc} <C:\Users\vivi\AppData\Local
# \MiKTeX\2.9\fonts/pk/ljfour/jknappen/ec/dpi600\tcit1095.pk> <C:\Users\vivi\AppD
# ata\Local\MiKTeX\2.9\fonts/pk/ljfour/jknappen/ec/dpi600\ecit1095.pk> <C:\Users\
# vivi\AppData\Local\MiKTeX\2.9\fonts/pk/ljfour/jknappen/ec/dpi600\tctt1095.pk> <
# C:\Users\vivi\AppData\Local\MiKTeX\2.9\fonts/pk/ljfour/jknappen/ec/dpi600\ectt1
# 095.pk><C:/Users/vivi/AppData/Local/Programs/MiKTeX 2.9/fonts/type1/public/amsf
# onts/cm/cmmi10.pfb><C:/Users/vivi/AppData/Local/Programs/MiKTeX 2.9/fonts/type1
# /public/amsfonts/cm/cmsy10.pfb><C:/Users/vivi/AppData/Local/Programs/MiKTeX 2.9
# /fonts/type1/urw/palatino/uplb8a.pfb><C:/Users/vivi/AppData/Local/Programs/MiKT
# eX 2.9/fonts/type1/urw/palatino/uplr8a.pfb><C:/Users/vivi/AppData/Local/Program
# s/MiKTeX 2.9/fonts/type1/urw/palatino/uplri8a.pfb>
# Output written on version2_presentation.pdf (17 pages, 330564 bytes).
# Transcript written on version2_presentation.log.
# [TerminalIPythonApp] WARNING | Subcommand `ipython nbconvert` is deprecated and will be removed in future versions.
# [TerminalIPythonApp] WARNING | You likely want to use `jupyter nbconvert` in the future
# [NbConvertApp] Converting notebook version2_presentation.ipynb to latex
# [NbConvertApp] Support files will be in version2_presentation_files\
# [NbConvertApp] Making directory version2_presentation_files
# [NbConvertApp] Making directory version2_presentation_files
# [NbConvertApp] Making directory version2_presentation_files
# [NbConvertApp] Making directory version2_presentation_files
# [NbConvertApp] Writing 90633 bytes to version2_presentation.tex

# %%
# %%bash
#
# jupyter nbconvert --to latex --template citations.tplx --post PyPDF2 QuadraticEquations.ipynb
# Out:
# This application is used to convert notebook files (*.ipynb) to various other
# formats.
#
# WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# -------
#
# Arguments that take values are actually convenience aliases to full
# Configurables, whose aliases are listed on the help line. For more information
# on full configurables, see '--help-all'.
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
# --generate-config
#     generate default config file
# -y
#     Answer yes to any questions instead of prompting.
# --execute
#     Execute the notebook prior to export.
# --allow-errors
#     Continue notebook execution even if one of the cells throws an error and include the error message in the cell output (the default behaviour is to abort conversion). This flag is only relevant if '--execute' was specified, too.
# --stdin
#     read a single notebook file from stdin. Write the resulting notebook with default basename 'notebook.*'
# --stdout
#     Write notebook output to stdout instead of files.
# --inplace
#     Run nbconvert in place, overwriting the existing notebook (only
#     relevant when converting to notebook format)
# --clear-output
#     Clear output of current file and save in place,
#     overwriting the existing notebook.
# --no-prompt
#     Exclude input and output prompts from converted document.
# --log-level=<Enum> (Application.log_level)
#     Default: 30
#     Choices: (0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL')
#     Set the log level by value or name.
# --config=<Unicode> (JupyterApp.config_file)
#     Default: ''
#     Full path of a config file.
# --to=<Unicode> (NbConvertApp.export_format)
#     Default: 'html'
#     The export format to be used, either one of the built-in formats, or a
#     dotted object name that represents the import path for an `Exporter` class
# --template=<Unicode> (TemplateExporter.template_file)
#     Default: ''
#     Name of the template file to use
# --writer=<DottedObjectName> (NbConvertApp.writer_class)
#     Default: 'FilesWriter'
#     Writer class used to write the  results of the conversion
# --post=<DottedOrNone> (NbConvertApp.postprocessor_class)
#     Default: ''
#     PostProcessor class used to write the results of the conversion
# --output=<Unicode> (NbConvertApp.output_base)
#     Default: ''
#     overwrite base name use for output files. can only be used when converting
#     one notebook at a time.
# --output-dir=<Unicode> (FilesWriter.build_directory)
#     Default: ''
#     Directory to write output(s) to. Defaults to output to the directory of each
#     notebook. To recover previous default behaviour (outputting to the current
#     working directory) use . as the flag value.
# --reveal-prefix=<Unicode> (SlidesExporter.reveal_url_prefix)
#     Default: ''
#     The URL prefix for reveal.js. This can be a a relative URL for a local copy
#     of reveal.js, or point to a CDN.
#     For speaker notes to work, a local reveal.js prefix must be used.
# --nbformat=<Enum> (NotebookExporter.nbformat_version)
#     Default: 4
#     Choices: [1, 2, 3, 4]
#     The nbformat version to write. Use this to downgrade notebooks.
#
# To see all available configurables, use `--help-all`
#
# Examples
# --------
#
#     The simplest way to use nbconvert is
#
#     > jupyter nbconvert mynotebook.ipynb
#
#     which will convert mynotebook.ipynb to the default format (probably HTML).
#
#     You can specify the export format with `--to`.
#     Options include ['asciidoc', 'custom', 'html', 'html_ch', 'html_embed', 'html_toc', 'html_with_lenvs', 'html_with_toclenvs', 'latex', 'latex_with_lenvs', 'markdown', 'notebook', 'pdf', 'python', 'rst', 'script', 'selectLanguage', 'slides', 'slides_with_lenvs']
#
#     > jupyter nbconvert --to latex mynotebook.ipynb
#
#     Both HTML and LaTeX support multiple output templates. LaTeX includes
#     'base', 'article' and 'report'.  HTML includes 'basic' and 'full'. You
#     can specify the flavor of the format used.
#
#     > jupyter nbconvert --to html --template basic mynotebook.ipynb
#
#     You can also pipe the output to stdout, rather than a file
#
#     > jupyter nbconvert mynotebook.ipynb --stdout
#
#     PDF is generated via latex
#
#     > jupyter nbconvert mynotebook.ipynb --to pdf
#
#     You can get (and serve) a Reveal.js-powered slideshow
#
#     > jupyter nbconvert myslides.ipynb --to slides --post serve
#
#     Multiple notebooks can be given at the command line in a couple of
#     different ways:
#
#     > jupyter nbconvert notebook*.ipynb
#     > jupyter nbconvert notebook1.ipynb notebook2.ipynb
#
#     or you can specify the notebooks list in a config file, containing::
#
#         c.NbConvertApp.notebooks = ["my_notebook.ipynb"]
#
#     > jupyter nbconvert --config mycfg.py
# [NbConvertApp] CRITICAL | Bad config encountered during initialization:
# [NbConvertApp] CRITICAL | The 'postprocessor_factory' trait of a NbConvertApp instance must be a subclass of 'builtins.object' or None, but a value of class 'module' (i.e. <module 'PyPDF2' from 'c:\\users\\vivi\\anaconda2\\envs\\tfp3.6\\lib\\site-packages\\PyPDF2\\__init__.py'>) was specified.

# %% [markdown]
# ### More information
# #### nbconvert
# - [Converting notebooks to other formats](https://ipython.org/ipython-doc/1/interactive/nbconvert.html)
#
# #### ipython citations tutorial
# - [Managing citations in the IPython Notebook](http://nbviewer.jupyter.org/github/ipython/nbconvert-examples/blob/master/citations/Tutorial.ipynb)
