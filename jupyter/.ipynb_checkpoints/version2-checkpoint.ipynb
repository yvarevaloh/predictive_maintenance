# %%
import pandas as pd
import numpy as np 
import random
from datetime import datetime
import seaborn as sns
from xgboost import XGBClassifier
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ParameterGrid
from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import PCA
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix,accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from collections import Counter 
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
import matplotlib.pyplot as plt
from sklearn import svm
import imblearn
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # Uploading the data

# %%
path_file = 'C:\\Users\\vivi\\Documents\\AWS\\proyect\\data\\device_failure.csv'

# %%
import csv
row_file = []
with open(path_file, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',')
    for row in spamreader:
        row_file.append(row)

# %%
df = pd.DataFrame(row_file[1:], columns = row_file[0], dtype = float) 
date_list = list(df['date']) 
date_time = [datetime.strptime(j,'%Y-%m-%d') for j in date_list]
df['date_time']= date_time
df=df.sort_values(['device','date_time'])
unique_device = df['device'].drop_duplicates()

# %%
dif_days=[]
for device in unique_device:
    sample_data = df[df['device']==device]
    dif_days_device = list(np.arange(0,sample_data.shape[0]))
    dif_days=dif_days+dif_days_device
df['day'] = dif_days

# %%
df.to_csv('C:\\Users\\vivi\\Documents\\AWS\\proyect\\data\\device_failure_dataframe.csv',index=False)

# %%
df.head()

# %% [markdown]
# # Exploratory Data Analysis

# %%
df=pd.read_csv('C:\\Users\\vivi\\Documents\\AWS\\proyect\\data\\device_failure_dataframe.csv')

# %%
print('Minimum date:',min(df['date']))
print('Maxiimum date:',max(df['date']))

# %%
varx=['attribute1','attribute2','attribute3','attribute4','attribute5','attribute6','attribute7','attribute8','attribute9','day']
df[varx].describe()

# %%
trans_data = pd.pivot_table(df[['date','device','failure']], values='failure', index=['device'], columns=['date'], aggfunc=np.sum)
trans_data_vec = list(trans_data.sum(axis = 0, skipna = True)) 
trans_data_vec =[sum(trans_data_vec[:j])/sum(trans_data_vec) for j in range(len(trans_data_vec))]
plt.plot(trans_data_vec)
plt.plot(total_device_day)
plt.ylabel('Total number of failures')
plt.show()

# %%
sns.boxplot(x='failure', y='attribute1', 
                 data=df, 
                 palette="colorblind")

# %% [markdown]
# # Preparing data from the model

# %%
df=pd.read_csv('C:\\Users\\vivi\\Documents\\AWS\\proyect\\data\\device_failure_dataframe.csv')

# %%
# total number of unique devices
df['device'].drop_duplicates().shape[0]
# Out:
# 1169

# %%
fail_devices = list(df[df['failure']==1.0]['device'].drop_duplicates())
print(len(fail_devices))
no_fail_devices = list(set(list(df['device'].drop_duplicates()))-set(fail_devices))
# Out:
# 106

# %%
y_fail = list(np.repeat(1,len(fail_devices)))+list(np.repeat(0,len(no_fail_devices)))
X_fail = fail_devices +  no_fail_devices

# %%
X_trainf, X_testf, y_trainf, y_testf = train_test_split(X_fail, y_fail, test_size=0.25, random_state=42,stratify=y_fail)

# %%
var = ['attribute1','attribute2','attribute3','attribute4','attribute5','attribute6','attribute7','attribute8','attribute9']
train = df[df['device'].isin(X_trainf)]
X_train = train[var]
y_train = train['failure']

test = df[df['device'].isin(X_testf)]
X_test = test[var]
y_test = test['failure']

# %%
print(Counter(list(y_trainf)))
print(Counter(list(y_testf)))
# Out:
# Counter({0: 637, 1: 64})
# Counter({0: 426, 1: 42})

# %%
print(74/(774+74)*100)
print((32/(32+319))*100)
# Out:
# 8.726415094339622
# 9.116809116809117

# %% [markdown]
# # Balancing the training dataset

# %%
# transform the dataset
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X_trainup, y_trainup = oversample.fit_resample(X_train, y_train)

# %%
Counter(y_trainup)
# Out:
# Counter({0.0: 98424, 1.0: 98424})

# %% [markdown]
# # Random Forest

# %%
clf = RandomForestClassifier(n_estimators=100, max_depth=2,random_state=0)
clf.fit(X_trainup, y_trainup)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=2, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
pd.DataFrame({'var':X_trainup.columns,'feature_importance':clf.feature_importances_}).sort_values(['feature_importance'],ascending=False)
# Out:
#           var  feature_importance
# 3  attribute4            0.340032
# 1  attribute2            0.291658
# 6  attribute7            0.163850
# 7  attribute8            0.163495
# 8  attribute9            0.021722
# 4  attribute5            0.012007
# 5  attribute6            0.004298
# 2  attribute3            0.001823
# 0  attribute1            0.001115

# %%
predictions=clf.predict(X_test)
confusion_matrix(y_test, predictions)
# Out:
# array([[30318,  2782],
#        [    7,    20]], dtype=int64)

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
auc = roc_auc_score(y_test, predictions)
print("AUC: %.2f%%" % (auc * 100.0))
F1=f1_score(y_test, predictions)
print("F1-score: %.2f%%" % (F1 * 100.0))
recall = recall_score(y_test, predictions)
print("recall: %.2f%%" % (recall * 100.0))
precision = precision_score(y_test, predictions)
print("precision: %.2f%%" % (precision * 100.0))
# Out:
# Accuracy: 91.58%
# AUC: 82.83%
# F1-score: 1.41%
# recall: 74.07%
# precision: 0.71%

# %%
Counter(y_train)
# Out:
# Counter({0.0: 84951, 1.0: 74})

# %% [markdown]
# # KNeighbors model

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X_trainup, y_trainup)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
predictions = neigh.predict(X_test)
confusion_matrix(y_test, predictions)
# Out:
# array([[26045,  7055],
#        [   18,     9]], dtype=int64)

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
auc = roc_auc_score(y_test, predictions)
print("AUC: %.2f%%" % (auc * 100.0))
F1=f1_score(y_test, predictions)
print("F1-score: %.2f%%" % (F1 * 100.0))
recall = recall_score(y_test, predictions)
print("recall: %.2f%%" % (recall * 100.0))
precision = precision_score(y_test, predictions)
print("precision: %.2f%%" % (precision * 100.0))
# Out:
# Accuracy: 78.65%
# AUC: 56.01%
# F1-score: 0.25%
# recall: 33.33%
# precision: 0.13%

# %% [markdown]
# # XGBoost model

# %%
model = XGBClassifier()

# %%
model.fit(X_trainup, y_trainup)
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#               validate_parameters=False, verbosity=None)

# %%
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[32955,   145],
#        [   22,     5]], dtype=int64)

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
auc = roc_auc_score(y_test, predictions)
print("AUC: %.2f%%" % (auc * 100.0))
F1=f1_score(y_test, predictions)
print("F1-score: %.2f%%" % (F1 * 100.0))
recall = recall_score(y_test, predictions)
print("recall: %.2f%%" % (recall * 100.0))
precision = precision_score(y_test, predictions)
print("precision: %.2f%%" % (precision * 100.0))
# Out:
# Accuracy: 99.50%
# AUC: 59.04%
# F1-score: 5.65%
# recall: 18.52%
# precision: 3.33%

# %%
from sklearn.model_selection import cross_val_score
model = XGBClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: %.5f' % mean(scores))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-227-80bc0a702a30> in <module>()
#       6 scores = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
#       7 # summarize performance
# ----> 8 print('Mean ROC AUC: %.5f' % mean(scores))
#
# NameError: name 'mean' is not defined

# %% [markdown]
# # Deep learning  model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.externals import joblib
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
# Out:
# c:\users\vivi\anaconda2\envs\tfp3.6\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
model = tf.keras.Sequential()
model.add(layers.Dense(150, input_shape=(9,),activation='relu'))
model.add(layers.Dense(100, activation='relu'))
model.add(layers.Dense(80, activation='relu'))
model.add(layers.Dense(50, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
X_trainup.shape
# Out:
# (169902, 9)

# %%
model.fit(X_trainup, y_trainup, epochs=20, batch_size=2000, validation_data=(X_test, y_test))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 145912 samples, validate on 51474 samples
# Epoch 1/20
# 145912/145912 [==============================] - 1s 9us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 2/20
# 145912/145912 [==============================] - 1s 9us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 3/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 4/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 5/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 6/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 7/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 8/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 9/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 10/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 11/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 12/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 13/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 14/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 15/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 16/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 17/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 18/20
# 145912/145912 [==============================] - 1s 8us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 19/20
# 145912/145912 [==============================] - 1s 9us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04
# Epoch 20/20
# 145912/145912 [==============================] - 1s 9us/sample - loss: 7.6666 - accuracy: 0.5000 - val_loss: 15.3207 - val_accuracy: 8.1595e-04

# %%
df[var].shape

# %%
df['failure'].shape
# Out:
# (124494,)

# %%
predict_XGboost = model.predict(df[var])
confusion_matrix(df['failure'], predict_XGboost)

df['y_pred']=predict_XGboost

# %%
accuracy = accuracy_score(df['failure'], predict_XGboost)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
auc = roc_auc_score(df['failure'], predict_XGboost)
print("AUC: %.2f%%" % (auc * 100.0))
F1=f1_score(df['failure'], predict_XGboost, average='weighted')
print("F1-score: %.2f%%" % (F1 * 100.0))
recall = recall_score(df['failure'], predict_XGboost, average='weighted')
print("recall: %.2f%%" % (recall * 100.0))
precision = precision_score(df['failure'], predict_XGboost, average='weighted')
print("precision: %.2f%%" % (precision * 100.0))
# Out:
# Accuracy: 99.77%
# AUC: 81.98%
# F1-score: 99.83%
# recall: 99.77%
# precision: 99.90%

# %%
X_fail
# Out:
# ['S1F023H2',
#  'S1F03YZM',
#  'S1F09DZQ',
#  'S1F0CTDN',
#  'S1F0DSTY',
#  'S1F0F4EB',
#  'S1F0GG8X',
#  'S1F0GJW3',
#  'S1F0GKFX',
#  'S1F0GKL6',
#  'S1F0GPFZ',
#  'S1F0GSD9',
#  'S1F0GSHB',
#  'S1F0J5JH',
#  'S1F0JD7P',
#  'S1F0JGJV',
#  'S1F0L0DW',
#  'S1F0LCTV',
#  'S1F0LCVC',
#  'S1F0LD15',
#  'S1F0LD2C',
#  'S1F0P3G2',
#  'S1F0PJJW',
#  'S1F0QF3R',
#  'S1F0QY11',
#  'S1F0RR35',
#  'S1F0RRB1',
#  'S1F0RSZP',
#  'S1F0S2WJ',
#  'S1F0S4CA',
#  'S1F0S4EG',
#  'S1F0S4T6',
#  'S1F0S57T',
#  'S1F0S65X',
#  'S1F0T2LA',
#  'S1F0TQCV',
#  'S1F10E6M',
#  'S1F11MB0',
#  'S1F13589',
#  'S1F135TN',
#  'S1F136J0',
#  'S1F13H80',
#  'W1F03D4L',
#  'W1F03DP4',
#  'W1F08EDA',
#  'W1F0F6BN',
#  'W1F0FKWW',
#  'W1F0FW0S',
#  'W1F0GCAZ',
#  'W1F0KCP2',
#  'W1F0M35B',
#  'W1F0M4BZ',
#  'W1F0NZZZ',
#  'W1F0P114',
#  'W1F0PAXH',
#  'W1F0PNA5',
#  'W1F0Q8FH',
#  'W1F0SGHR',
#  'W1F0T034',
#  'W1F0T074',
#  'W1F0T0B1',
#  'W1F0TA59',
#  'W1F0VDH2',
#  'W1F0WBTM',
#  'W1F0X4FC',
#  'W1F0X5GW',
#  'W1F0Z1W9',
#  'W1F0Z3KR',
#  'W1F0Z4EA',
#  'W1F11ZG9',
#  'W1F1230J',
#  'W1F13SRV',
#  'W1F14XGD',
#  'W1F15S4D',
#  'W1F19BPT',
#  'W1F1BFP5',
#  'W1F1BS0H',
#  'W1F1BZTM',
#  'W1F1C9TE',
#  'W1F1C9WG',
#  'W1F1CB5E',
#  'W1F1CDDP',
#  'W1F1CJ1K',
#  'W1F1DQN8',
#  'Z1F04GCH',
#  'Z1F0B4XZ',
#  'Z1F0FSBY',
#  'Z1F0K451',
#  'Z1F0LSNZ',
#  'Z1F0LVGY',
#  'Z1F0LVPW',
#  'Z1F0MCCA',
#  'Z1F0MRPJ',
#  'Z1F0NVZA',
#  'Z1F0P16F',
#  'Z1F0P5D9',
#  'Z1F0QH0C',
#  'Z1F130LH',
#  'Z1F148T1',
#  'Z1F14BGY',
#  'Z1F1653X',
#  'Z1F1901P',
#  'Z1F1AG5N',
#  'Z1F1FCH5',
#  'Z1F1RJFA',
#  'Z1F1VQFY',
#  'S1F0S351',
#  'W1F1DN0Y',
#  'S1F0PF5Q',
#  'Z1F0LH7B',
#  'Z1F0LL7D',
#  'W1F0X5JV',
#  'S1F11DBJ',
#  'Z1F0N8QM',
#  'W1F0W8BD',
#  'W1F0W0RV',
#  'S1F0TP75',
#  'S1F0R3N9',
#  'S1F11YHR',
#  'S1F10GDQ',
#  'Z1F0LSXW',
#  'Z1F0LVL5',
#  'W1F0X5KT',
#  'Z1F0BA45',
#  'W1F0MW4S',
#  'W1F14H94',
#  'Z1F0M0XP',
#  'Z1F0QKA2',
#  'Z1F0KQWF',
#  'W1F0L6ZS',
#  'W1F0T371',
#  'S1F0S52H',
#  'W1F0BJ6E',
#  'W1F1BG0P',
#  'S1F12ZQB',
#  'S1F0RTQV',
#  'W1F1D8GZ',
#  'S1F0QWWF',
#  'S1F122HQ',
#  'W1F1CCGF',
#  'S1F1359T',
#  'W1F0T474',
#  'W1F0HPZK',
#  'W1F0NB60',
#  'W1F0W9SR',
#  'W1F14HAQ',
#  'Z1F19ENW',
#  'S1F0S5VX',
#  'Z1F0E2J2',
#  'W1F0SWST',
#  'S1F135WP',
#  'W1F0X47B',
#  'S1F135SZ',
#  'W1F0VL6W',
#  'Z1F0QK7Z',
#  'S1F133YJ',
#  'Z1F1Q9BD',
#  'S1F0S649',
#  'W1F1FHEK',
#  'S1F0FW8K',
#  'S1F0X4RC',
#  'S1F0GPXY',
#  'W1F1BGAB',
#  'W1F0RN8N',
#  'W1F0TAEP',
#  'W1F1DA55',
#  'W1F0WJHE',
#  'W1F1CK1V',
#  'W1F0T960',
#  'W1F0M492',
#  'S1F01TD5',
#  'W1F12JLS',
#  'S1F0R4Q8',
#  'Z1F16LDN',
#  'W1F0X5JF',
#  'W1F0P6E1',
#  'W1F0JEB8',
#  'W1F1354W',
#  'W1F1335J',
#  'Z1F0AM4J',
#  'Z1F282ZV',
#  'Z1F0AHAT',
#  'W1F0M46R',
#  'S1F10FFZ',
#  'S1F0TPMF',
#  'W1F0GPGR',
#  'W1F0JA9T',
#  'W1F0AQ9Q',
#  'S1F0G9ZF',
#  'Z1F0L6BY',
#  'W1F10Y8K',
#  'S1F0S5B2',
#  'S1F0QZYJ',
#  'W1F0KCN8',
#  'W1F0M330',
#  'Z1F0N7VR',
#  'Z1F0M7QD',
#  'W1F0VAS7',
#  'W1F0X7P2',
#  'S1F13BQX',
#  'W1F0WMPM',
#  'S1F12XGM',
#  'Z1F0MYEL',
#  'S1F02W1L',
#  'S1F0Y6BM',
#  'W1F0WKE1',
#  'Z1F16G31',
#  'S1F1368E',
#  'W1F0ZDTJ',
#  'S1F0S6EY',
#  'W1F0KHHQ',
#  'W1F1CMG4',
#  'W1F095DW',
#  'Z1F11RAE',
#  'Z1F0LNQB',
#  'W1F0G99N',
#  'S1F0SBF5',
#  'Z1F0BF9X',
#  'S1F0QY05',
#  'S1F1327G',
#  'Z1F0LRLQ',
#  'S1F0LCQX',
#  'S1F13HWA',
#  'W1F1DQ6A',
#  'S1F10V1N',
#  'S1F0PL0R',
#  'S1F0318A',
#  'S1F1318D',
#  'S1F0S5F0',
#  'S1F0LDKM',
#  'S1F0SBJA',
#  'S1F049RX',
#  'Z1F1A7MG',
#  'W1F14NBM',
#  'S1F12ZAS',
#  'S1F0S68M',
#  'S1F1358N',
#  'S1F135F0',
#  'W1F0JXDL',
#  'Z1F0W23J',
#  'W1F0KCR5',
#  'S1F0RR0C',
#  'S1F0SBXC',
#  'Z1F11B2R',
#  'S1F0LR01',
#  'W1F1CM57',
#  'W1F0VC83',
#  'W1F1ZVME',
#  'S1F0R37Q',
#  'W1F1CLH3',
#  'W1F0T3H5',
#  'S1F0RR69',
#  'W1F0X5KX',
#  'W1F0WKMJ',
#  'S1F02DZ2',
#  'W1F0ZG5V',
#  'W1F1N6V6',
#  'Z1F0KZ3H',
#  'S1F13635',
#  'S1F0S7DN',
#  'S1F0KYCR',
#  'W1F0X44B',
#  'S1F05AFP',
#  'S1F0BQZK',
#  'W1F1AN6A',
#  'W1F0H973',
#  'W1F1CMJW',
#  'S1F13KC2',
#  'S1F0TCGQ',
#  'S1F11WEH',
#  'S1F0L11K',
#  'W1F0FYLJ',
#  'W1F06RAW',
#  'Z1F0LVEM',
#  'W1F0TK8P',
#  'S1F13BTN',
#  'W1F0N84F',
#  'Z1F11BHF',
#  'S1F0TKSC',
#  'S1F0166B',
#  'W1F0SFJJ',
#  'S1F0TQQ1',
#  'S1F0TP8F',
#  'Z1F0RGQV',
#  'W1F0X6TM',
#  'W1F1NSHB',
#  'S1F0LCS6',
#  'W1F1CMVW',
#  'Z1F1FZ9J',
#  'S1F135BR',
#  'W1F13B09',
#  'S1F05P5Z',
#  'W1F08B0G',
#  'S1F0RS3B',
#  'S1F04R7Y',
#  'W1F0KAX2',
#  'Z1F1A1HH',
#  'S1F0S4MG',
#  'W1F11FCC',
#  'Z1F0WPTF',
#  'Z1F1A83K',
#  'S1F12Y53',
#  'S1F0TPJC',
#  'S1F0S3DF',
#  'W1F0SVA7',
#  'W1F0Z2JE',
#  'W1F0VDS7',
#  'S1F0R20R',
#  'S1F02L38',
#  'W1F1CMCY',
#  'W1F0X4F6',
#  'W1F0X47W',
#  'W1F0HTQ2',
#  'Z1F02KDL',
#  'S1F0LQDQ',
#  'S1F0VE11',
#  'W1F0X6KZ',
#  'W1F0VVMM',
#  'S1F0RSZZ',
#  'S1F0R2VP',
#  'S1F0RR2E',
#  'S1F0R3JV',
#  'W1F0AQGD',
#  'W1F0ZK0H',
#  'W1F0Z62G',
#  'S1F0QY1C',
#  'W1F1C51R',
#  'W1F1DX8D',
#  'S1F0C95J',
#  'Z1F26YZB',
#  'S1F0377V',
#  'S1F100R5',
#  'S1F135QH',
#  'W1F1BRM3',
#  'S1F06R6W',
#  'S1F02XLX',
#  'W1F0VF0M',
#  'W1F1DN3S',
#  'Z1F0KSLS',
#  'S1F0CSBR',
#  'S1F0CWHW',
#  'S1F13CBB',
#  'W1F0RXV0',
#  'S1F0TNSA',
#  'S1F0S6HH',
#  'S1F02MGA',
#  'Z1F16BR1',
#  'W1F111C6',
#  'W1F0FY92',
#  'Z1F0R8FZ',
#  'W1F0X5L8',
#  'W1F0VL4Q',
#  'S1F130GX',
#  'W1F0P2M4',
#  'S1F0B5QJ',
#  'S1F114QM',
#  'S1F0RREN',
#  'S1F09MAK',
#  'S1F13KBJ',
#  'S1F0G0XX',
#  'S1F0CWKN',
#  'S1F02WFT',
#  'W1F0Z4X2',
#  'Z1F17Z3N',
#  'W1F0YKEW',
#  'W1F0WKLP',
#  'W1F0976M',
#  'W1F18TKX',
#  'S1F0PG6Z',
#  'S1F13HPR',
#  'S1F0PGZ6',
#  'S1F0S34Q',
#  'S1F0TNYF',
#  'W1F0KG97',
#  'Z1F0LKMJ',
#  'W1F0JHRJ',
#  'Z1F0LM6T',
#  'Z1F19QM3',
#  'S1F11S2Q',
#  'S1F0RSFT',
#  'S1F13MAM',
#  'W1F0A27Q',
#  'S1F0RR7L',
#  'W1F0KCZ0',
#  'Z1F2PBHX',
#  'W1F0X5L3',
#  'S1F0QXYA',
#  'S1F0PK70',
#  'S1F10FF0',
#  'S1F0QZ0P',
#  'W1F0JY02',
#  'S1F0QWEQ',
#  'S1F0S4G4',
#  'S1F119X9',
#  'S1F0LDB5',
#  'W1F0SJNS',
#  'S1F13JW4',
#  'S1F03RV3',
#  'Z1F0E1CS',
#  'Z1F0QZJB',
#  'Z1F156MQ',
#  'W1F0TJ66',
#  'S1F0S613',
#  'W1F09WLS',
#  'S1F0QWPP',
#  'S1F04DH8',
#  'S1F0S387',
#  'Z1F0MSSJ',
#  'S1F0KY6R',
#  'S1F0TKW7',
#  'W1F1BS9T',
#  'S1F0QYX3',
#  'W1F1CJ3G',
#  'S1F0Y8MA',
#  'Z1F0MYCF',
#  'S1F0PGHQ',
#  'W1F0WW7E',
#  'S1F0QY71',
#  'Z1F0QSB1',
#  'S1F0KZJJ',
#  'S1F0R2S6',
#  'S1F132A5',
#  'W1F1CHZK',
#  'S1F122KD',
#  'W1F14NE5',
#  'S1F0RSDT',
#  'Z1F0LR8G',
#  'S1F0CWXJ',
#  'W1F0MZRT',
#  'W1F0QKJP',
#  'Z1F0L4T5',
#  'W1F0QE96',
#  'S1F13B32',
#  'S1F04TS4',
#  'W1F0SJJ2',
#  'W1F0JA75',
#  'Z1F19TVX',
#  'Z1F19KMH',
#  'S1F0RSMR',
#  'W1F17GR6',
#  'S1F0QWYG',
#  'S1F1021H',
#  'S1F0SC17',
#  'Z1F0Q8RT',
#  'W1F0JAZB',
#  'S1F135GA',
#  'S1F0S0NC',
#  'S1F0R4JY',
#  'S1F0TPS0',
#  'S1F04MVQ',
#  'S1F0RSWJ',
#  'S1F0TQTH',
#  'W1F0W6QD',
#  'S1F0GCED',
#  'Z1F0MP8Q',
#  'S1F136FG',
#  'Z1F1B6H4',
#  'S1F0RVG8',
#  'W1F0G0NT',
#  'S1F0RSML',
#  'S1F0QWGA',
#  'W1F0X5HV',
#  'S1F10PED',
#  'W1F1NTWG',
#  'Z1F0QQ5F',
#  'S1F0LD73',
#  'W1F11CR1',
#  'S1F0S4GB',
#  'S1F1360W',
#  'W1F0S9SP',
#  'W1F0HYT8',
#  'S1F013BB',
#  'S1F10VP8',
#  'W1F0X7PR',
#  'Z1F0L78Z',
#  'W1F0P2TN',
#  'S1F0R12B',
#  'S1F0QX41',
#  'S1F0S33G',
#  'W1F0SRG1',
#  'W1F1CZLY',
#  'S1F135CE',
#  'Z1F0MA1S',
#  'Z1F1HSWK',
#  'W1F0J7W7',
#  'W1F14GWF',
#  'Z1F0LT3Y',
#  'W1F1BQTN',
#  'W1F0KRWP',
#  'S1F12788',
#  'S1F0DKAN',
#  'W1F0THAD',
#  'S1F0R0PX',
#  'W1F034ZE',
#  'W1F1CAKS',
#  'W1F0TGSS',
#  'S1F0TQP1',
#  'W1F0DXT8',
#  'S1F10EBC',
#  'W1F0LSFS',
#  'W1F1DQJD',
#  'W1F14GTK',
#  'S1F0TQEJ',
#  'S1F0RSG7',
#  'S1F116H4',
#  'S1F12ZRR',
#  'Z1F0L613',
#  'S1F0GHJ1',
#  'W1F0WN8P',
#  'S1F0S6B7',
#  'Z1F0LT6P',
#  'W1F0ZVD8',
#  'Z1F0QKGH',
#  'W1F0P24E',
#  'S1F0R12Y',
#  'W1F1DQR9',
#  'W1F0N0DC',
#  'W1F0NBYN',
#  'S1F13KNV',
#  'W1F0W2DH',
#  'S1F134QM',
#  'S1F039FE',
#  'S1F02EVN',
#  'S1F10JL3',
#  'W1F1ARYY',
#  'S1F0TND9',
#  'S1F0YX6Z',
#  'S1F0BN0S',
#  'S1F0GRB1',
#  'W1F06QVP',
#  'W1F0J9KM',
#  'S1F0TP5E',
#  'W1F18YT8',
#  'S1F0WWHD',
#  'S1F13KBZ',
#  'W1F181WP',
#  'S1F101MC',
#  'S1F03499',
#  'W1F1CJ27',
#  'Z1F19VF5',
#  'S1F0SAC1',
#  'W1F1DABR',
#  'S1F0S6GZ',
#  'S1F0R4YC',
#  'W1F0WLZP',
#  'S1F0QYBJ',
#  'W1F05X69',
#  'S1F0TQTF',
#  'W1F0WRX5',
#  'Z1F0FAZJ',
#  'S1F0QYJX',
#  'W1F0H9RN',
#  'W1F0Z4X0',
#  'S1F0S7B7',
#  'S1F0SBLG',
#  'S1F0322R',
#  'S1F115Z6',
#  'W1F0Z56F',
#  'W1F1Q5EF',
#  'W1F111Q7',
#  'W1F0HR3T',
#  'S1F0MBV5',
#  'Z1F0MR6M',
#  'W1F0THPN',
#  'Z1F0DZAQ',
#  'W1F0W1R9',
#  'S1F0Y4H6',
#  'S1F0QY0Q',
#  'S1F0PJAJ',
#  'Z1F19QH0',
#  'S1F0TQ7S',
#  'W1F0V8CY',
#  'S1F0QYX4',
#  'W1F0Z569',
#  'Z1F0MTFT',
#  'S1F0S58D',
#  'S1F11K34',
#  'W1F1C0R9',
#  'W1F1CMFD',
#  'S1F0CTDY',
#  'W1F17E35',
#  'Z1F0QH7R',
#  'W1F1DPSA',
#  'W1F1CLBY',
#  'S1F135D3',
#  'W1F0W3GE',
#  'W1F0Z491',
#  'W1F0L2Q7',
#  'S1F0A1VP',
#  'S1F11A9R',
#  'S1F10HH5',
#  'Z1F15HYM',
#  'S1F0A1PX',
#  'S1F0GV0W',
#  'S1F0QXCB',
#  'Z1F19TP2',
#  'W1F0FZPA',
#  'W1F0HT26',
#  'S1F13KG3',
#  'S1F10GSG',
#  'S1F0E9EP',
#  'S1F10BNL',
#  'S1F0S537',
#  'W1F1MRP9',
#  'W1F1DA5ÿ',
#  'S1F0TQLY',
#  'Z1F02NBQ',
#  'S1F0BVK1',
#  'Z1F0D8DV',
#  'Z1F1AFT5',
#  'S1F0S561',
#  'W1F0TCG0',
#  'Z1F1479Y',
#  'Z1F0KJDS',
#  'S1F0QXM0',
#  'Z1F17XPD',
#  'W1F0W5AQ',
#  'Z1F0LLKC',
#  'Z1F1A0RP',
#  'S1F0LLKM',
#  'W1F0X5J5',
#  'S1F0RSXC',
#  'Z1F0LKBP',
#  'W1F0HSKB',
#  'W1F0X6V0',
#  'Z1F0L7NZ',
#  'W1F14N6K',
#  'S1F0LDED',
#  'Z1F15VY4',
#  'S1F0PF59',
#  'S1F1364P',
#  'Z1F0LLPS',
#  'S1F117PK',
#  'S1F11B1E',
#  'W1F0X4VZ',
#  'Z1F0LB4J',
#  'S1F0S4QZ',
#  'Z1F0MWE7',
#  'W1F0LZJX',
#  'S1F0QY8S',
#  'S1F0T2FN',
#  'S1F12ZZ2',
#  'S1F0QXRG',
#  'S1F13GPY',
#  'S1F135F3',
#  'S1F0RVVR',
#  'W1F0LS71',
#  'S1F0PXZL',
#  'W1F0T13Q',
#  'W1F0M6Y0',
#  'S1F0S66R',
#  'S1F10QH3',
#  'W1F0W685',
#  'S1F0TMLM',
#  'W1F1BFHS',
#  'Z1F1AFF2',
#  'W1F1CJXM',
#  'Z1F0LH7E',
#  'W1F14XK6',
#  'W1F1C9HM',
#  'Z1F0LSQ2',
#  'S1F0SBBW',
#  'S1F136BS',
#  'W1F0G9T7',
#  'W1F0NF1S',
#  'W1F1CKXZ',
#  'Z1F0LT4K',
#  'Z1F0LV93',
#  'S1F0RSER',
#  'S1F0S5WJ',
#  'W1F12JRF',
#  'W1F0P41T',
#  'Z1F0LQGS',
#  'W1F0X3MJ',
#  'S1F0H6JG',
#  'S1F11Y4K',
#  'W1F1N4CT',
#  'S1F0S6VR',
#  'Z1F1AGLA',
#  'S1F0RV6Z',
#  'S1F0TP82',
#  'S1F0FZ8F',
#  'S1F0FGBQ',
#  'S1F0S517',
#  'W1F0TQEE',
#  'W1F0VZF4',
#  'W1F0X3PR',
#  'S1F0QYRS',
#  'Z1F0GE1M',
#  'S1F0T29K',
#  'S1F0EGSH',
#  'Z1F1473X',
#  'S1F12XJ4',
#  'S1F0PJZP',
#  'W1F1BFRJ',
#  'W1F0Z4SP',
#  'W1F1D899',
#  'S1F10NM6',
#  'Z1F0LBT6',
#  'W1F0LYY0',
#  'S1F0QYLA',
#  'W1F1GLFN',
#  'Z1F0ZCPW',
#  'S1F035SJ',
#  'W1F0X711',
#  'S1F0QX4C',
#  'W1F14FS4',
#  'S1F06E04',
#  'Z1F02MRX',
#  'S1F130JB',
#  'W1F0X3ZX',
#  'S1F0QXXH',
#  'S1F1162D',
#  'S1F121LH',
#  'S1F0QWZP',
#  'W1F0T3LK',
#  'S1F0TP6E',
#  'W1F0R731',
#  'Z1F0L2VS',
#  'S1F0TNW4',
#  'S1F0S5LP',
#  'S1F0LCSV',
#  'Z1F151C1',
#  'S1F13CMG',
#  'Z1F0M0TV',
#  'Z1F1CZ35',
#  'S1F0S382',
#  'S1F0RRXY',
#  'Z1F0R9TM',
#  'S1F0RS72',
#  'S1F0S3CR',
#  'S1F11KAY',
#  'W1F0SWXK',
#  'W1F0X4CX',
#  'W1F1MTM2',
#  'Z1F0QL3N',
#  'S1F06F7K',
#  'S1F0S5YZ',
#  'W1F1CKJZ',
#  'W1F0VL7M',
#  'W1F11JQW',
#  'Z1F0LSPT',
#  'W1F0KD3Y',
#  'Z1F0MQJ2',
#  'Z1F11SYE',
#  'S1F0T1K8',
#  'S1F0R2RJ',
#  'Z1F0GB8A',
#  'Z1F0QKEW',
#  'W1F1BFMS',
#  'W1F0VJXT',
#  'S1F0S454',
#  'W1F1CKKW',
#  'S1F10NDB',
#  'S1F05B1Q',
#  'S1F11AXR',
#  'Z1F1VMZB',
#  'W1F1DQQT',
#  'W1F0YKBQ',
#  'S1F01E6Y',
#  'S1F0XMNV',
#  'Z1F1632F',
#  'W1F0X70N',
#  'S1F0P1K7',
#  'S1F0SAB1',
#  'Z1F0L7NS',
#  'S1F0QZSF',
#  'Z1F0LKWC',
#  'Z1F0L4Y0',
#  'Z1F0G55J',
#  'S1F0R2CW',
#  'W1F0WJFT',
#  'W1F16RA7',
#  'S1F10FDX',
#  'S1F13KF6',
#  'W1F1GMWX',
#  'S1F0GGPP',
#  'S1F0QYPA',
#  'Z1F0LLKR',
#  'W1F0WK71',
#  'W1F09HBX',
#  'S1F0T22E',
#  'W1F0X5VA',
#  'S1F11KQW',
#  'S1F0GJL9',
#  'W1F0VKTT',
#  'S1F0TQCF',
#  'W1F0QTJM',
#  'W1F0YJ6K',
#  'W1F0X4TS',
#  'Z1F0LSHN',
#  'W1F08KZW',
#  'S1F0M2PQ',
#  'S1F0SCHE',
#  'S1F13432',
#  'S1F131F6',
#  'S1F0QZXV',
#  'W1F0VFRE',
#  'S1F0CVY5',
#  'S1F0RRDW',
#  'S1F136JY',
#  'W1F1FZ8B',
#  'S1F0LL2X',
#  'S1F135DN',
#  'Z1F0LCDA',
#  'S1F0S02A',
#  'S1F0LCKH',
#  'S1F11G2C',
#  'W1F1CLED',
#  'S1F0QYRB',
#  'S1F0TPK1',
#  'W1F17DKS',
#  'W1F0VJT2',
#  'Z1F0LJTD',
#  'S1F06ZX2',
#  'S1F0RQLR',
#  'S1F10D0P',
#  'S1F0SBHA',
#  'S1F0EGMT',
#  'S1F0S5SR',
#  'S1F0QWGD',
#  'W1F0W63P',
#  'Z1F18YST',
#  'S1F0S363',
#  'W1F0R8W2',
#  'S1F0TQR9',
#  'S1F135DG',
#  'S1F12ZQN',
#  'S1F0PL7D',
#  'W1F1CKSX',
#  'W1F1D93M',
#  'Z1F0R8QZ',
#  'S1F0R4JP',
#  'W1F0Z4CF',
#  'W1F0TXKY',
#  'S1F0GGJD',
#  'S1F0W45F',
#  'S1F0CVRM',
#  'S1F12ZSD',
#  'Z1F161QC',
#  'Z1F11SL0',
#  'W1F0KD47',
#  'Z1F1AD0M',
#  'S1F0GQCL',
#  'S1F0RR5M',
#  'Z1F0L4S8',
#  'Z1F0LT6Z',
#  'S1F0QXTJ',
#  'W1F0M02P',
#  'W1F0X6VJ',
#  'W1F0Z3FW',
#  'S1F0PK2J',
#  'W1F08PYR',
#  'W1F0X5N2',
#  'S1F136KG',
#  'Z1F0LLWH',
#  'W1F0NZSK',
#  'W1F1BAE6',
#  'S1F0T1BB',
#  'Z1F1HEQR',
#  'W1F1A4H9',
#  'S1F0CVWK',
#  'S1F0TPYB',
#  'S1F13K8E',
#  'Z1F1AF54',
#  'S1F0R2VR',
#  'Z1F0MBGF',
#  'Z1F0RGNJ',
#  'W1F0Z588',
#  'S1F0R3FB',
#  'S1F0S6L1',
#  'W1F0Z4W7',
#  'W1F0HJWZ',
#  'S1F0R3LG',
#  'S1F01JE0',
#  'Z1F0RL5B',
#  'S1F10RWZ',
#  'W1F09H4J',
#  'S1F0QXVD',
#  'W1F1BW8W',
#  'Z1F0LLFY',
#  'S1F0F4G4',
#  'S1F0QYMX',
#  'S1F10P0S',
#  'W1F1BFZT',
#  'W1F0VZFH',
#  'W1F0P133',
#  'S1F0QXDQ',
#  'W1F0Y13C',
#  'S1F11C16',
#  'S1F11ETS',
#  'Z1F0L7PX',
#  'W1F1AQ6G',
#  'S1F10VJH',
#  'S1F0T1AC',
#  'W1F1CNV3',
#  'W1F03CRZ',
#  'W1F1BTB2',
#  'W1F1CHY9',
#  'W1F0X4ZX',
#  'Z1F0WVLC',
#  'Z1F1652D',
#  'Z1F17ZCN',
#  'S1F1365W',
#  'Z1F0LLPJ',
#  'W1F0JAZC',
#  'S1F1073Z',
#  'W1F0W2BX',
#  'S1F0SCT6',
#  'S1F0TQJ4',
#  'S1F0S70T',
#  'Z1F06WA0',
#  'S1F0TQ9G',
#  'S1F05NAJ',
#  'W1F0TYQ9',
#  'S1F0SCPM',
#  'W1F0KD36',
#  'W1F1CJKT',
#  'S1F0S5E9',
#  'W1F133A0',
#  'S1F0LEBM',
#  'Z1F1A0CJ',
#  'W1F0LZFB',
#  'S1F0S6AB',
#  'Z1F0KKN4',
#  'S1F13619',
#  'W1F0XKWR',
#  'S1F0330P',
#  'Z1F0CBSH',
#  'S1F11MT9',
#  'S1F0CTRL',
#  'S1F0TMRF',
#  'W1F0Z3G1',
#  'W1F0L66L',
#  'S1F01XDJ',
#  'Z1F0LTAV',
#  'W1F0T3AJ',
#  'W1F1CLNF',
#  'W1F1CL8Q',
#  'S1F0T24J',
#  'S1F13M9A',
#  'W1F111N7',
#  'Z1F1RE71',
#  'Z1F0LKEE',
#  'S1F0PLEL',
#  'S1F0RKT7',
#  'W1F1CK5G',
#  'W1F08RHG',
#  'W1F0W5XL',
#  'W1F12KWT',
#  'S1F02P76',
#  'S1F0CVDS',
#  'Z1F0QK05',
#  'W1F0LBD3',
#  'S1F0S34C',
#  'Z1F0L3BL',
#  'S1F0S1QK',
#  'Z1F1A0LM',
#  'W1F0AQDE',
#  'S1F11GG5',
#  'S1F118JP',
#  'S1F0R2KW',
#  'S1F0FVBE',
#  'W1F07EWB',
#  'W1F0SCL1',
#  'W1F0X5TL',
#  'W1F097FV',
#  'W1F0X5KA',
#  'S1F11S5B',
#  'Z1F0Q9H0',
#  'S1F0LBY2',
#  'S1F0RS81',
#  'W1F03Y44',
#  'S1F01R2B',
#  'Z1F0L7M8',
#  'S1F0CSRZ',
#  'W1F0K9C1',
#  'Z1F04CA7',
#  'S1F0LE2X',
#  'Z1F1R76A',
#  'S1F09MSM',
#  'S1F0S5CE',
#  'S1F0S4Y9',
#  'S1F0TD9A',
#  'W1F08J1G',
#  'S1F116J4',
#  'S1F0S30R',
#  'Z1F0PSHD',
#  'Z1F0LQMH',
#  'Z1F1B799',
#  'W1F0X6SQ',
#  'W1F1NS0C',
#  'Z1F0QGSE',
#  'S1F136A5',
#  'Z1F0LM11',
#  'S1F0S4WV',
#  'S1F0HWXJ',
#  'S1F01085',
#  'W1F0VA0G',
#  'W1F0X4AK',
#  ...]

# %%
df[df['device']=='S1F023H2'].sort_values(['device','date_time'])
# Out:
#            date    device  failure   attribute1  attribute2  attribute3  \
# 407  2015-01-01  S1F023H2      0.0  141503600.0         0.0         0.0
# 408  2015-01-02  S1F023H2      0.0  161679800.0         0.0         0.0
# 409  2015-01-03  S1F023H2      0.0  182358672.0         0.0         0.0
# 410  2015-01-04  S1F023H2      0.0  204752808.0         0.0         0.0
# 411  2015-01-05  S1F023H2      0.0  226982888.0         0.0         0.0
# 412  2015-01-06  S1F023H2      0.0   10387472.0         0.0         0.0
# 413  2015-01-07  S1F023H2      0.0   30083248.0         0.0         0.0
# 414  2015-01-08  S1F023H2      0.0   55079280.0         0.0         0.0
# 415  2015-01-09  S1F023H2      0.0   78898848.0         0.0         0.0
# 416  2015-01-10  S1F023H2      0.0  107573856.0         0.0         0.0
# 417  2015-01-11  S1F023H2      0.0  134464552.0         0.0         0.0
# 418  2015-01-12  S1F023H2      0.0  156754936.0         0.0         0.0
# 419  2015-01-13  S1F023H2      0.0  177478384.0         0.0         0.0
# 420  2015-01-14  S1F023H2      0.0  203744280.0         0.0         0.0
# 421  2015-01-15  S1F023H2      0.0  222474632.0         0.0         0.0
# 422  2015-01-16  S1F023H2      0.0  243825496.0         0.0         0.0
# 423  2015-01-17  S1F023H2      0.0   20761856.0         0.0         0.0
# 424  2015-01-18  S1F023H2      0.0   41291000.0         0.0         0.0
# 425  2015-01-19  S1F023H2      1.0   64499464.0         0.0         0.0
#
#      attribute4  attribute5  attribute6  attribute7  attribute8  attribute9  \
# 407         1.0        19.0    494462.0        16.0        16.0         3.0
# 408         1.0        19.0    495730.0        16.0        16.0         3.0
# 409         1.0        19.0    496974.0        16.0        16.0         3.0
# 410         1.0        19.0    497559.0        16.0        16.0         3.0
# 411         1.0        19.0    498753.0        16.0        16.0         3.0
# 412         1.0        19.0    499964.0        16.0        16.0         3.0
# 413         1.0        19.0    501239.0        16.0        16.0         3.0
# 414         1.0        19.0    502542.0        16.0        16.0         3.0
# 415         1.0        19.0    503812.0        16.0        16.0         3.0
# 416         1.0        19.0    505079.0        16.0        16.0         3.0
# 417         1.0        19.0    505504.0        16.0        16.0         3.0
# 418         1.0        19.0    506684.0        16.0        16.0         3.0
# 419         1.0        19.0    507971.0        16.0        16.0         3.0
# 420         1.0        19.0    509250.0        16.0        16.0         3.0
# 421         1.0        19.0    510519.0        16.0        16.0         3.0
# 422         1.0        19.0    511783.0        16.0        16.0         3.0
# 423         1.0        19.0    513110.0        16.0        16.0         3.0
# 424         1.0        19.0    513722.0        16.0        16.0         3.0
# 425         1.0        19.0    514661.0        16.0        16.0         3.0
#
#       date_time  day  y_pred
# 407  2015-01-01    0     0.0
# 408  2015-01-02    1     0.0
# 409  2015-01-03    2     0.0
# 410  2015-01-04    3     0.0
# 411  2015-01-05    4     0.0
# 412  2015-01-06    5     0.0
# 413  2015-01-07    6     0.0
# 414  2015-01-08    7     0.0
# 415  2015-01-09    8     0.0
# 416  2015-01-10    9     0.0
# 417  2015-01-11   10     0.0
# 418  2015-01-12   11     0.0
# 419  2015-01-13   12     0.0
# 420  2015-01-14   13     0.0
# 421  2015-01-15   14     0.0
# 422  2015-01-16   15     0.0
# 423  2015-01-17   16     0.0
# 424  2015-01-18   17     0.0
# 425  2015-01-19   18     1.0
